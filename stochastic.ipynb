# %%
import numpy as np
import matplotlib as plt

# %%
span_len = 10
# sample Monte Carlo output distribution
var_obs = 0.67
obs_err = 0.2

# %%
# Create APCEMM input dataset
#--------------------------------------------------------------------------------------------------
APCEMM_input = np.zeros(span_len)

for i in range(span_len):
    # sample Monte Carlo output distribution
    var_rand = np.random.normal(loc=var_obs, scale=obs_err, size=None)

    APCEMM_input[i] = var_rand
# Out:
# [0.73243088 0.41665731 0.7513407  0.61430106 0.78142142 0.09645603
#  0.55007491 0.83410196 0.45203124 0.46183339]

# %%
#Run APCEMM with created dataset

# %%
delta  =  var_rand/var_obs
eta = var_rand - var_obs*delta

# calculate variance and mean

# calculate corrected var
#var_cor =
