# %%
import numpy as np
import pandas as pd

# %%
# For PCE
print("Initial Condition: ", np.random.normal(1, 0.3, 10))
print("Time varying: ", np.random.normal(0, 1, 10))
# Out:
# Initial Condition:  [1.14139085 0.91154268 0.69971412 0.44328824 0.61805568 0.96161021
#  1.13385713 0.91461322 1.3050061  1.14236564]
# Time varying:  [-0.92632684  0.08841273 -2.15689666 -0.62783741  1.44743813 -0.62311206
#  -1.26159099  0.77084914 -0.65232313 -0.77999665]

# %%
# For Validation
print(np.random.normal(70,5,10))
print(np.random.normal(80,10,10))
