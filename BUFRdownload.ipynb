# %%
# BUFR data download and proccess
import tarfile

# %%
# open file
file = tarfile.open('gfg.tar.gz')
  
# extracting file
file.extractall('/home/chinahg/GCresearch/contrailuncertainty/BUFR_files')
  
file.close()
