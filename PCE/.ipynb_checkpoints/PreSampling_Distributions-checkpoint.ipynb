# %%
import numpy as np
import pandas as pd

# %%
# For PCE
print("Initial Condition: ", np.random.normal(0,5,10))
print("Time varying: ", np.random.normal(0,10,10))
# Out:
# [61.32230556 73.62477888 58.0307141  71.44898345 67.94112938 66.02835855
#  69.83956119 65.5921258  68.37184417 64.28067062]
# [76.48762653 67.77378957 80.90122187 62.67630573 75.89121538 92.05564011
#  67.61394739 73.07193794 74.74419897 67.0566219 ]
# [1143.9446124  1236.99228429  744.98514405  858.29135335  887.03265345
#  1406.23609121 1158.10653013  706.3319266   899.46789937 1217.91484301]

# %%
# For Validation
print(np.random.normal(70,5,10))
print(np.random.normal(80,10,10))
